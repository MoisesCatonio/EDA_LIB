# %%
# Importando o pandas e 
import pandas as pd

datasets_urls = [
            {"nome": "exemplares", "url": "https://drive.google.com/uc?export=download&id=1v1oik1Kev5a9XLcF2tzcSI-5QE5TIkJD"},
            {"nome": "acervo", "url": "https://drive.google.com/uc?export=download&id=1s9SZ2PS8tWjZ9BWYybPGm92G7gwXU7yO"},
            {"nome": "emp_2009_2", "url": "https://drive.google.com/uc?export=download&id=1DwXJmGCqaZh-dToW5W08L6PqhyfTjrVn"},
            {"nome": "emp_2010_1", "url": "https://drive.google.com/uc?export=download&id=1Lon0QojcXJuWY04WzNk7U10WgC2xNVzV"},
            {"nome": "emp_2010_2", "url": "https://drive.google.com/uc?export=download&id=1WVAThK0Ya4hhFbtyXcjfiCkE1tFirKp_"},
            {"nome": "emp_2011_1", "url": "https://drive.google.com/uc?export=download&id=1ANuI-G3LcyqUDRd8MrcgpI_qgkxIWW6N"},
            {"nome": "emp_2011_2", "url": "https://drive.google.com/uc?export=download&id=1icsbMGd_JxK6NzL6U_ndR5O1Yr6SmMNU"},
            {"nome": "emp_2012_1", "url": "https://drive.google.com/uc?export=download&id=16O9fbsr3T58IZlnFaW9CLvASUN1nWMfB"},
            {"nome": "emp_2012_2", "url": "https://drive.google.com/uc?export=download&id=1sFBrLHPgXaTkjbuZrZ4XFcMEFCb_mczl"},
            {"nome": "emp_2013_1", "url": "https://drive.google.com/uc?export=download&id=1OnwyVCydV-ZLi4RP-XD3AZOqP2YfsiGu"},
            {"nome": "emp_2013_2", "url": "https://drive.google.com/uc?export=download&id=1SOUj8ma10yWFSrWR_6NVvWK5V6EW8LN_"},
            {"nome": "emp_2014_1", "url": "https://drive.google.com/uc?export=download&id=1rvHJQ0_EZtkqR03RKJUftFWfkKNVdA7H"},
            {"nome": "emp_2014_2", "url": "https://drive.google.com/uc?export=download&id=16qYRQ_-IAqVAcNqklSLFbH5GmePxT8MO"},
            {"nome": "emp_2015_1", "url": "https://drive.google.com/uc?export=download&id=1MpSY7fQqU9yGY9l_6CF4zqOGE51J3pBj"},
            {"nome": "emp_2015_2", "url": "https://drive.google.com/uc?export=download&id=137_QYLteqHR8_GEWzX2oMPuZ4XU4SxMF"},
            {"nome": "emp_2016_1", "url": "https://drive.google.com/uc?export=download&id=1yioitFb2jbZS1nv6tJqI_MXBwSuduGpj"},
            {"nome": "emp_2016_2", "url": "https://drive.google.com/uc?export=download&id=14Fh0jxuJAnf5_6phDvB94rwApMXPR9xV"},
            {"nome": "emp_2017_1", "url": "https://drive.google.com/uc?export=download&id=1u_1-3obAlYtScPU_Ewdj76GsgjbalGnp"},
            {"nome": "emp_2017_2", "url": "https://drive.google.com/uc?export=download&id=1VH6-fwlGUwBKGMpxqD6_tur5aBBEqXoZ"},
            {"nome": "emp_2018_1", "url": "https://drive.google.com/uc?export=download&id=1SPbGdSzx26RB4KIgKz1dyw_Hl03h_GPV"},
            {"nome": "emp_2018_2", "url": "https://drive.google.com/uc?export=download&id=14WZ1zduwNrAn1NEXQgqsWAN-mSIUYOmd"},
            {"nome": "emp_2019_1", "url": "https://drive.google.com/uc?export=download&id=12l4S9PpD2mdDRllN267KUrAlsAdWX4Ru"},
            ]

datasets = {}
for ds_url in datasets_urls:
  datasets[ds_url["nome"]] = pd.read_csv(ds_url["url"], sep = ';')

# %%
datasets["emp_2019_1"].columns

# %%
#Concatenando todos os datasets adquiridos em um único.
datasets2 = []
for ds_url in datasets_urls:
  datasets2.append(pd.read_csv(ds_url["url"], sep = ';'))
for dataset in datasets2[1:]:
  datasets2[0] = pd.concat([dataset, datasets2[0]], axis = 0)
dados = datasets2[0]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
#Verificando a existência de uma das matrículas e aplicando as nossas colunas de ética.
ing_2011 = pd.read_csv("http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/2bb3dec9-7f23-434c-a179-21515f91abc8/download/discentes-2011.csv", sep=";")
ing_2011.loc[ing_2011.matricula == 2011058100][['matricula','nivel_ensino','nome_curso','nome_unidade_gestora']]
# Out:
#        matricula nivel_ensino nome_curso                  nome_unidade_gestora
# 1146  2011058100    GRADUAÇÃO   GEOLOGIA  CENTRO DE CIÊNCIAS EXATAS E DA TERRA

# %%
#Quantidade de empréstimos realizados por cada matrícula ou siape desde 2009.2
dados['matricula_ou_siape'].value_counts()
# Out:
# 198422044.0      710
# 198624283.0      607
# 2011058100.0     592
# 198623384.0      556
# 2015073769.0     550
# 2012964077.0     470
# 3766151.0        455
# 20170079870.0    450
# 1636627.0        446
# 2015073320.0     446
# 1669214.0        444
# 2016082468.0     430
# 1513790.0        427
# 198690057.0      427
# 2011025585.0     421
# 2012932411.0     416
# 1758023.0        407
# 20152021183.0    392
# 2014063605.0     387
# 2016091260.0     386
# 2008012921.0     384
# 2010023650.0     378
# 2015073722.0     378
# 2014096713.0     375
# 2016083741.0     370
# 3523714.0        368
# 2015102163.0     366
# 2015046888.0     363
# 1603496.0        358
# 2016016598.0     350
#                 ...
# 20180113545.0      1
# 20180007337.0      1
# 2015318262.0       1
# 2010038665.0       1
# 2015317390.0       1
# 20162004103.0      1
# 199022767.0        1
# 2011125339.0       1
# 2013070534.0       1
# 200645293.0        1
# 20190013964.0      1
# 2013019890.0       1
# ...

# %%
#capturando apenas os exemplares regulares, com possibilidade de empréstimo
exemplares_biblioteca = datasets["exemplares"]
exemplares_biblioteca_regulares = exemplares_biblioteca.loc[exemplares_biblioteca.status_material == "REGULAR"]

# %%
exemplares_biblioteca.count()
# Out:
# id_exemplar         559341
# codigo_barras       559341
# colecao             559341
# biblioteca          559341
# status_material     559341
# localizacao         559284
# registro_sistema    559341
# dtype: int64

# %%
#capturando apenas os exemplares da BCZM
regulares_bczm = exemplares_biblioteca_regulares.loc[exemplares_biblioteca_regulares.biblioteca == "Biblioteca Central Zila Mamede"]
bczm_v1 = exemplares_biblioteca.loc[exemplares_biblioteca.biblioteca == "Biblioteca Central Zila Mamede"]

# %%
regulares_bczm.count()
# Out:
# id_exemplar         215617
# codigo_barras       215617
# colecao             215617
# biblioteca          215617
# status_material     215617
# localizacao         215591
# registro_sistema    215617
# dtype: int64

# %%
bczm_v1.head()

#versao 1 do dataset possui menos exemplares do que a nova versão
# Out:
#    id_exemplar codigo_barras  ...          localizacao registro_sistema
# 0            3       L000001  ...  304(812/814)  A168n                1
# 1            4       L000002  ...   304(812/814) A168n                1
# 2            5       L000003  ...  304(812/814)  A168n                1
# 3            7       L000114  ...          159.9 A228m                5
# 4            9       L000040  ...          317.3  B79s               14
#
# [5 rows x 7 columns]

# %%
bczm_v1.loc[bczm_v1.titulo == "Administração da produção /"]
#existe um registro no dataset para cada exemplar, mesmo havendo o número de materiais ativos no dataset

# %%
regulares_bczm.loc[regulares_bczm.codigo_barras == "L197999"]
#existem 3 colunas para identificação do livro = id_exemplar, codigo_barras, registro
# Out:
#         id_exemplar codigo_barras  ...        localizacao registro_sistema
# 169660       179217       L197999  ...  541.1 A874f 3.ed.            68551
#
# [1 rows x 7 columns]

# %%
#O padrão de colunas se manteve desde o dataset inicial para nossa pesquisa. 
datasets["emp_2009_2"].columns == datasets["emp_2019_1"].columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
#Leitura dos empréstimos em 2019.1
datasets["emp_2019_1"].matricula_ou_siape.value_counts()

# %%
#Aumento de precisão do display, para retirar a notação científica.
pd.set_option('display.precision',12)

#Pessoas com mais empréstimos em 2019.1
datasets["emp_2019_1"].matricula_ou_siape.value_counts().head()

#datasets["emp_2019_1"].loc[datasets["emp_2019_1"].matricula_ou_siape == 20190113001]
# Out:
# 20190113001.0    90
# 20183023441.0    70
# 20183023067.0    69
# 20180114702.0    69
# 20180076156.0    58
# Name: matricula_ou_siape, dtype: int64

# %%
#Que coincidência não? :]
#Aplicamos os filtros de coluna para respeitar quesitos pessoais dos indivíduos apresentados na pesquisa
ing_2019_1 = pd.read_csv("http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/a55aef81-e094-4267-8643-f283524e3dd7/download/discentes-2019.csv", sep=";")
ing_2019_1.loc[ing_2019_1.matricula == 20190113001][['matricula','nivel_ensino','nome_curso','nome_unidade_gestora']]
# Out:
#          matricula  ...                         nome_unidade_gestora
# 12089  20190113001  ...  UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE
#
# [1 rows x 4 columns]

# %%
#Vendo os outros alunos com mais empréstimos do head
ing_2018 = pd.read_csv("http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/146b749b-b9d0-49b2-b114-ac6cc82a4051/download/discentes-2018.csv", sep=";")
x = ing_2018.loc[ing_2018.matricula == 20183023441][['matricula','nivel_ensino','nome_curso','nome_unidade_gestora']]
y = ing_2018.loc[ing_2018.matricula == 20183023067][['matricula','nivel_ensino','nome_curso','nome_unidade_gestora']]
z = ing_2018.loc[ing_2018.matricula == 20180114702][['matricula','nivel_ensino','nome_curso','nome_unidade_gestora']]
w = ing_2018.loc[ing_2018.matricula == 20180076156][['matricula','nivel_ensino','nome_curso','nome_unidade_gestora']]

# %%
#Aluno com 70 empréstimos
x

# %%
#Aluno com 69 empréstimos
y

# %%
#Aluno com 69 empréstimos
z

# %%
#Aluno com 58 empréstimos
w
